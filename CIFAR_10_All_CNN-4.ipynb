# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
# Out:
# /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /lib64/libz.so.1: version `ZLIB_1.2.9' not found (required by /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/../../../libpng16.so.16)
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
load_from_chkpt = True # Load from checkpoint in case of resuming training

# %%
transform = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
transform_blur = transforms.Compose([
                                     transforms.Resize((8,8)),
                                     transforms.Resize((32,32),interpolation=InterpolationMode.BILINEAR),
                                     transforms.RandomCrop(32, padding=4),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

# CIFAR 10 Dataset
train_dataset_clean = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform,
                                             download=True)

train_dataset_blur = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform_blur,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='./data/',
                                            train=False, 
                                            transform=transform)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128

train_loader_clean = torch.utils.data.DataLoader(dataset=train_dataset_clean,
                                           batch_size=batch_size, 
                                           shuffle=True)

train_loader_blur = torch.utils.data.DataLoader(dataset=train_dataset_blur,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
# def imshow(img, fig_title):
#     # img = img / 2 + 0.5
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg.squeeze()))
#     plt.title(fig_title)
#     plt.show()
    


# # get some random training images and show
# dataiter_blur = iter(train_loader_blur)
# images_blur, labels_blur = dataiter_blur.next()
# imshow(torchvision.utils.make_grid(images_blur), "Blurred images")
# # print(' '.join(f'{classes[labels_blur[j]]:5s}' for j in range(batch_size)))

# dataiter_clean = iter(train_loader_clean)
# images_clean, labels_clean = dataiter_clean.next()
# imshow(torchvision.utils.make_grid(images_clean), "Clean images")
# # print(' '.join(f'{classes[labels_clean[j]]:5s}' for j in range(batch_size)))

# %%
class AllCNNNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.dp0 = nn.Dropout2d(p = 0.2)
    self.conv1 = nn.Conv2d(3, 96, 3, padding=1)
    self.conv2 = nn.Conv2d(96, 96, 3, padding=1)
    self.conv3 = nn.Conv2d(96, 192, 3, stride=2, padding=1)
    self.dp1 = nn.Dropout2d(p = 0.5)
    self.conv4 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv5 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv6 = nn.Conv2d(192, 192, 3, stride=2, padding=1)
    self.dp2 = nn.Dropout2d(p = 0.5)
    self.conv7 = nn.Conv2d(192, 192, 3, padding=0)
    self.conv8 = nn.Conv2d(192, 192, 1)
    self.conv9 = nn.Conv2d(192, 10, 1)
    self.avg = nn.AvgPool2d(6)

    nn.init.xavier_normal_(self.conv1.weight)
    nn.init.xavier_normal_(self.conv2.weight)
    nn.init.xavier_normal_(self.conv3.weight)
    nn.init.xavier_normal_(self.conv4.weight)
    nn.init.xavier_normal_(self.conv5.weight)
    nn.init.xavier_normal_(self.conv6.weight)
    nn.init.xavier_normal_(self.conv7.weight)
    nn.init.xavier_normal_(self.conv8.weight)
    nn.init.xavier_normal_(self.conv9.weight)

  def forward(self, x):
    x = self.dp0(x)
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = self.dp1(x)
    x = F.relu(self.conv4(x))
    x = F.relu(self.conv5(x))
    x = F.relu(self.conv6(x))
    x = self.dp2(x)
    x = F.relu(self.conv7(x))
    x = F.relu(self.conv8(x))
    x = F.relu(self.conv9(x))
    x = self.avg(x)
    x = torch.squeeze(x)
    # x = F.softmax(x, dim=0)
    return x

net = AllCNNNet().to(device)

# %%
# class AllCNNNet(nn.Module):
#   def __init__(self):
#     super().__init__()
#     self.conv1 = nn.Conv2d(3, 6, 5)
#     self.pool = nn.MaxPool2d(2, 2)
#     self.conv2 = nn.Conv2d(6, 16, 5)
#     self.fc1 = nn.Linear(16*5*5, 120)
#     self.fc2 = nn.Linear(120, 84)
#     self.fc3 = nn.Linear(84, 10)

#   def forward(self, x):
#     x = self.pool(F.relu(self.conv1(x)))
#     x = self.pool(F.relu(self.conv2(x)))
#     x = torch.flatten(x, 1)
#     x = F.relu(self.fc1(x))
#     x = F.relu(self.fc2(x))
#     x = self.fc3(x)
#     return x

# net = AllCNNNet().to(device)

# %%
# Hyper-parameters
num_epochs_blur = 160
num_epochs_clean = 160
learning_rate = 0.05

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)
# optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# from torchsummary import summary

# summary(net, (3, 32, 32))

# %%
# For updating learning rate
def update_lr(optimizer, lr):    
#     print ("Updating LR")
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
num_epochs = num_epochs_blur + num_epochs_clean
total_step = len(train_loader_clean)
curr_lr = learning_rate
loss_plot = []
accuracy_plot = []
epoch_chkpt = 0

if(load_from_chkpt):
  # Load model from checkpoint
  path_chkpt = "./chkpt_5/model.pt"
  loss_plot_chkpt = "./chkpt_5/loss_plot.npy"
  acc_plot_chkpt = "./chkpt_5/acc_plot.npy"
  model = net
#   optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)

  checkpoint = torch.load(path_chkpt)
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch_chkpt = checkpoint['epoch']
  loss = checkpoint['loss']
  curr_lr = checkpoint['curr_lr']
  loss_plot = np.append(loss_plot, np.load(loss_plot_chkpt))
  accuracy_plot = np.append(accuracy_plot, np.load(acc_plot_chkpt))

  model.train()
  print("!!!Loaded from checkpoint!!! Epoch:{} Loss:{} curr_lr:{}".format(epoch_chkpt, loss, curr_lr))

for epoch in range(epoch_chkpt, num_epochs):  # loop over the dataset multiple times
  if epoch < num_epochs_blur:
    train_loader = train_loader_blur
    print("Using blur")
  else:
    train_loader = train_loader_clean
    print("Using clean")

  # running_loss = 0.0
  for i, (inputs, labels) in enumerate(train_loader):
      inputs = inputs.to(device)
      labels = labels.to(device)

      # forward + backward + optimize
      outputs = net(inputs)
      loss = criterion(outputs, labels)

      # zero the parameter gradients
      optimizer.zero_grad()
      loss.backward()


      optimizer.step()
      loss_plot = np.append(loss_plot, loss.item())

      if (i+1) % 100 == 0:
        print ("Epoch [{}/{}], Step [{}/{}] Loss: {:.4f} LR: {:.4f}"
                .format(epoch+1, num_epochs, i+1, total_step, loss.item(), curr_lr))

  # Decay learning rate
  curr_lr = 0.97 * curr_lr
  update_lr(optimizer, curr_lr)

  correct = 0
  total = 0
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in test_loader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

  accuracy_temp = 100 * correct // total
  print(f'Accuracy of the network : {accuracy_temp} %')
  accuracy_plot = np.append(accuracy_plot, accuracy_temp)

  if (epoch+1)==2 or (epoch+1)%25==0:
    # Save model checkpoint
    epoch_chkpt = epoch+1
    path_chkpt = "./chkpt_5/model.pt"
    loss_plot_chkpt = './chkpt_5/loss_plot.npy'
    acc_plot_chkpt = './chkpt_5/acc_plot.npy'
    loss_chkpt = loss.item()

    torch.save({
                'epoch': epoch_chkpt,
                'model_state_dict': net.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss_chkpt,
                'curr_lr': curr_lr,
                }, path_chkpt)
    np.save(loss_plot_chkpt, loss_plot)
    np.save(acc_plot_chkpt, accuracy_plot)
    print('!!!Checkpoint saved!!!')

print('Finished Training')
# Out:
# !!!Loaded from checkpoint!!! Epoch:200 Loss:0.6653571128845215 curr_lr:0.0001130620504997884
# Using clean
# Epoch [201/320], Step [100/391] Loss: 0.6757 LR: 0.0001
# Epoch [201/320], Step [200/391] Loss: 0.7295 LR: 0.0001
# Epoch [201/320], Step [300/391] Loss: 0.6281 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [202/320], Step [100/391] Loss: 0.7413 LR: 0.0001
# Epoch [202/320], Step [200/391] Loss: 0.6510 LR: 0.0001
# Epoch [202/320], Step [300/391] Loss: 0.5546 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [203/320], Step [100/391] Loss: 0.6007 LR: 0.0001
# Epoch [203/320], Step [200/391] Loss: 0.5752 LR: 0.0001
# Epoch [203/320], Step [300/391] Loss: 0.5709 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [204/320], Step [100/391] Loss: 0.5607 LR: 0.0001
# Epoch [204/320], Step [200/391] Loss: 0.7633 LR: 0.0001
# Epoch [204/320], Step [300/391] Loss: 0.6365 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [205/320], Step [100/391] Loss: 0.8147 LR: 0.0001
# Epoch [205/320], Step [200/391] Loss: 0.6930 LR: 0.0001
# Epoch [205/320], Step [300/391] Loss: 0.8737 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [206/320], Step [100/391] Loss: 0.6621 LR: 0.0001
# Epoch [206/320], Step [200/391] Loss: 0.8329 LR: 0.0001
# Epoch [206/320], Step [300/391] Loss: 0.6706 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [207/320], Step [100/391] Loss: 0.6294 LR: 0.0001
# Epoch [207/320], Step [200/391] Loss: 0.6676 LR: 0.0001
# Epoch [207/320], Step [300/391] Loss: 0.8762 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [208/320], Step [100/391] Loss: 1.0544 LR: 0.0001
# Epoch [208/320], Step [200/391] Loss: 0.8676 LR: 0.0001
# Epoch [208/320], Step [300/391] Loss: 0.8076 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [209/320], Step [100/391] Loss: 0.8421 LR: 0.0001
# Epoch [209/320], Step [200/391] Loss: 0.7196 LR: 0.0001
# Epoch [209/320], Step [300/391] Loss: 0.8267 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [210/320], Step [100/391] Loss: 0.6767 LR: 0.0001
# Epoch [210/320], Step [200/391] Loss: 0.6834 LR: 0.0001
# Epoch [210/320], Step [300/391] Loss: 0.6902 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [211/320], Step [100/391] Loss: 0.6533 LR: 0.0001
# Epoch [211/320], Step [200/391] Loss: 0.6647 LR: 0.0001
# Epoch [211/320], Step [300/391] Loss: 0.7205 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [212/320], Step [100/391] Loss: 0.7675 LR: 0.0001
# Epoch [212/320], Step [200/391] Loss: 0.8622 LR: 0.0001
# Epoch [212/320], Step [300/391] Loss: 0.7685 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [213/320], Step [100/391] Loss: 0.7624 LR: 0.0001
# Epoch [213/320], Step [200/391] Loss: 0.7571 LR: 0.0001
# Epoch [213/320], Step [300/391] Loss: 0.7808 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [214/320], Step [100/391] Loss: 0.7832 LR: 0.0001
# Epoch [214/320], Step [200/391] Loss: 0.6697 LR: 0.0001
# Epoch [214/320], Step [300/391] Loss: 0.8107 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [215/320], Step [100/391] Loss: 0.9012 LR: 0.0001
# Epoch [215/320], Step [200/391] Loss: 0.7066 LR: 0.0001
# Epoch [215/320], Step [300/391] Loss: 0.7199 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [216/320], Step [100/391] Loss: 0.6450 LR: 0.0001
# Epoch [216/320], Step [200/391] Loss: 0.6582 LR: 0.0001
# Epoch [216/320], Step [300/391] Loss: 0.7152 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [217/320], Step [100/391] Loss: 0.6739 LR: 0.0001
# Epoch [217/320], Step [200/391] Loss: 0.9200 LR: 0.0001
# Epoch [217/320], Step [300/391] Loss: 0.6134 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [218/320], Step [100/391] Loss: 0.7066 LR: 0.0001
# Epoch [218/320], Step [200/391] Loss: 0.7262 LR: 0.0001
# Epoch [218/320], Step [300/391] Loss: 0.6865 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [219/320], Step [100/391] Loss: 0.6988 LR: 0.0001
# Epoch [219/320], Step [200/391] Loss: 0.8652 LR: 0.0001
# Epoch [219/320], Step [300/391] Loss: 0.7375 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [220/320], Step [100/391] Loss: 0.7054 LR: 0.0001
# Epoch [220/320], Step [200/391] Loss: 0.6709 LR: 0.0001
# Epoch [220/320], Step [300/391] Loss: 0.7457 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [221/320], Step [100/391] Loss: 0.7955 LR: 0.0001
# Epoch [221/320], Step [200/391] Loss: 0.7270 LR: 0.0001
# Epoch [221/320], Step [300/391] Loss: 0.7068 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [222/320], Step [100/391] Loss: 0.7953 LR: 0.0001
# Epoch [222/320], Step [200/391] Loss: 0.5853 LR: 0.0001
# Epoch [222/320], Step [300/391] Loss: 0.7181 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [223/320], Step [100/391] Loss: 0.6759 LR: 0.0001
# Epoch [223/320], Step [200/391] Loss: 0.6572 LR: 0.0001
# Epoch [223/320], Step [300/391] Loss: 0.8577 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [224/320], Step [100/391] Loss: 0.5893 LR: 0.0001
# Epoch [224/320], Step [200/391] Loss: 0.6148 LR: 0.0001
# Epoch [224/320], Step [300/391] Loss: 0.6927 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [225/320], Step [100/391] Loss: 0.5903 LR: 0.0001
# Epoch [225/320], Step [200/391] Loss: 0.7481 LR: 0.0001
# Epoch [225/320], Step [300/391] Loss: 0.5857 LR: 0.0001
# Accuracy of the network : 72 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [226/320], Step [100/391] Loss: 0.6898 LR: 0.0001
# Epoch [226/320], Step [200/391] Loss: 0.7411 LR: 0.0001
# Epoch [226/320], Step [300/391] Loss: 0.6677 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [227/320], Step [100/391] Loss: 0.7112 LR: 0.0001
# Epoch [227/320], Step [200/391] Loss: 0.6935 LR: 0.0001
# Epoch [227/320], Step [300/391] Loss: 0.6717 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [228/320], Step [100/391] Loss: 0.8997 LR: 0.0000
# Epoch [228/320], Step [200/391] Loss: 0.6289 LR: 0.0000
# Epoch [228/320], Step [300/391] Loss: 0.5338 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [229/320], Step [100/391] Loss: 0.6702 LR: 0.0000
# Epoch [229/320], Step [200/391] Loss: 0.8015 LR: 0.0000
# Epoch [229/320], Step [300/391] Loss: 0.6833 LR: 0.0000
# Accuracy of the network : 71 %
# Using clean
# Epoch [230/320], Step [100/391] Loss: 0.7185 LR: 0.0000
# Epoch [230/320], Step [200/391] Loss: 0.7119 LR: 0.0000
# Epoch [230/320], Step [300/391] Loss: 0.7641 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [231/320], Step [100/391] Loss: 0.7454 LR: 0.0000
# Epoch [231/320], Step [200/391] Loss: 0.7659 LR: 0.0000
# Epoch [231/320], Step [300/391] Loss: 0.9351 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [232/320], Step [100/391] Loss: 0.8027 LR: 0.0000
# Epoch [232/320], Step [200/391] Loss: 0.6577 LR: 0.0000
# Epoch [232/320], Step [300/391] Loss: 0.7550 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [233/320], Step [100/391] Loss: 0.7985 LR: 0.0000
# Epoch [233/320], Step [200/391] Loss: 0.7080 LR: 0.0000
# Epoch [233/320], Step [300/391] Loss: 0.7523 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [234/320], Step [100/391] Loss: 0.7747 LR: 0.0000
# Epoch [234/320], Step [200/391] Loss: 0.5766 LR: 0.0000
# Epoch [234/320], Step [300/391] Loss: 0.6628 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [235/320], Step [100/391] Loss: 0.7494 LR: 0.0000
# Epoch [235/320], Step [200/391] Loss: 0.7279 LR: 0.0000
# Epoch [235/320], Step [300/391] Loss: 0.7356 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [236/320], Step [100/391] Loss: 0.8513 LR: 0.0000
# Epoch [236/320], Step [200/391] Loss: 0.6311 LR: 0.0000
# Epoch [236/320], Step [300/391] Loss: 0.5919 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [237/320], Step [100/391] Loss: 0.7861 LR: 0.0000
# Epoch [237/320], Step [200/391] Loss: 0.4335 LR: 0.0000
# Epoch [237/320], Step [300/391] Loss: 0.8032 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [238/320], Step [100/391] Loss: 0.6133 LR: 0.0000
# Epoch [238/320], Step [200/391] Loss: 0.6535 LR: 0.0000
# Epoch [238/320], Step [300/391] Loss: 0.8372 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [239/320], Step [100/391] Loss: 0.6556 LR: 0.0000
# Epoch [239/320], Step [200/391] Loss: 0.6565 LR: 0.0000
# Epoch [239/320], Step [300/391] Loss: 0.6085 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [240/320], Step [100/391] Loss: 0.8509 LR: 0.0000
# Epoch [240/320], Step [200/391] Loss: 0.8754 LR: 0.0000
# Epoch [240/320], Step [300/391] Loss: 0.6985 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [241/320], Step [100/391] Loss: 0.7434 LR: 0.0000
# Epoch [241/320], Step [200/391] Loss: 0.6625 LR: 0.0000
# Epoch [241/320], Step [300/391] Loss: 0.8269 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [242/320], Step [100/391] Loss: 0.7933 LR: 0.0000
# Epoch [242/320], Step [200/391] Loss: 0.7449 LR: 0.0000
# Epoch [242/320], Step [300/391] Loss: 0.6179 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [243/320], Step [100/391] Loss: 0.6019 LR: 0.0000
# Epoch [243/320], Step [200/391] Loss: 0.6731 LR: 0.0000
# Epoch [243/320], Step [300/391] Loss: 0.5768 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [244/320], Step [100/391] Loss: 0.6082 LR: 0.0000
# Epoch [244/320], Step [200/391] Loss: 0.6397 LR: 0.0000
# Epoch [244/320], Step [300/391] Loss: 0.8592 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [245/320], Step [100/391] Loss: 0.8215 LR: 0.0000
# Epoch [245/320], Step [200/391] Loss: 0.8054 LR: 0.0000
# Epoch [245/320], Step [300/391] Loss: 0.5985 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [246/320], Step [100/391] Loss: 0.8007 LR: 0.0000
# Epoch [246/320], Step [200/391] Loss: 0.6527 LR: 0.0000
# Epoch [246/320], Step [300/391] Loss: 0.6911 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [247/320], Step [100/391] Loss: 0.8209 LR: 0.0000
# Epoch [247/320], Step [200/391] Loss: 0.6302 LR: 0.0000
# Epoch [247/320], Step [300/391] Loss: 0.7959 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [248/320], Step [100/391] Loss: 0.5969 LR: 0.0000
# Epoch [248/320], Step [200/391] Loss: 0.7121 LR: 0.0000
# Epoch [248/320], Step [300/391] Loss: 0.6965 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [249/320], Step [100/391] Loss: 0.6172 LR: 0.0000
# Epoch [249/320], Step [200/391] Loss: 0.6007 LR: 0.0000
# Epoch [249/320], Step [300/391] Loss: 0.7768 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [250/320], Step [100/391] Loss: 0.6323 LR: 0.0000
# Epoch [250/320], Step [200/391] Loss: 0.5479 LR: 0.0000
# Epoch [250/320], Step [300/391] Loss: 0.6356 LR: 0.0000
# Accuracy of the network : 72 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [251/320], Step [100/391] Loss: 0.6498 LR: 0.0000
# Epoch [251/320], Step [200/391] Loss: 0.7390 LR: 0.0000
# Epoch [251/320], Step [300/391] Loss: 0.7954 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [252/320], Step [100/391] Loss: 0.5990 LR: 0.0000
# Epoch [252/320], Step [200/391] Loss: 0.7299 LR: 0.0000
# Epoch [252/320], Step [300/391] Loss: 0.8121 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [253/320], Step [100/391] Loss: 1.0549 LR: 0.0000
# Epoch [253/320], Step [200/391] Loss: 0.8528 LR: 0.0000
# Epoch [253/320], Step [300/391] Loss: 0.7598 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [254/320], Step [100/391] Loss: 0.7205 LR: 0.0000
# Epoch [254/320], Step [200/391] Loss: 0.7564 LR: 0.0000
# Epoch [254/320], Step [300/391] Loss: 0.8177 LR: 0.0000
# Accuracy of the network : 71 %
# Using clean
# Epoch [255/320], Step [100/391] Loss: 0.8792 LR: 0.0000
# Epoch [255/320], Step [200/391] Loss: 0.7798 LR: 0.0000
# Epoch [255/320], Step [300/391] Loss: 0.6880 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [256/320], Step [100/391] Loss: 0.7803 LR: 0.0000
# Epoch [256/320], Step [200/391] Loss: 0.7126 LR: 0.0000
# Epoch [256/320], Step [300/391] Loss: 0.8064 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [257/320], Step [100/391] Loss: 0.8952 LR: 0.0000
# Epoch [257/320], Step [200/391] Loss: 0.6700 LR: 0.0000
# Epoch [257/320], Step [300/391] Loss: 0.8234 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [258/320], Step [100/391] Loss: 0.5636 LR: 0.0000
# Epoch [258/320], Step [200/391] Loss: 0.7025 LR: 0.0000
# Epoch [258/320], Step [300/391] Loss: 0.8583 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [259/320], Step [100/391] Loss: 0.8163 LR: 0.0000
# Epoch [259/320], Step [200/391] Loss: 0.5824 LR: 0.0000
# Epoch [259/320], Step [300/391] Loss: 0.6761 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [260/320], Step [100/391] Loss: 0.7890 LR: 0.0000
# Epoch [260/320], Step [200/391] Loss: 0.7681 LR: 0.0000
# Epoch [260/320], Step [300/391] Loss: 0.7994 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [261/320], Step [100/391] Loss: 0.5880 LR: 0.0000
# Epoch [261/320], Step [200/391] Loss: 0.6509 LR: 0.0000
# Epoch [261/320], Step [300/391] Loss: 0.8038 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [262/320], Step [100/391] Loss: 0.7098 LR: 0.0000
# Epoch [262/320], Step [200/391] Loss: 0.6975 LR: 0.0000
# Epoch [262/320], Step [300/391] Loss: 0.7437 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [263/320], Step [100/391] Loss: 0.6804 LR: 0.0000
# Epoch [263/320], Step [200/391] Loss: 0.6588 LR: 0.0000
# Epoch [263/320], Step [300/391] Loss: 0.7477 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [264/320], Step [100/391] Loss: 0.6484 LR: 0.0000
# Epoch [264/320], Step [200/391] Loss: 0.6223 LR: 0.0000
# Epoch [264/320], Step [300/391] Loss: 0.7751 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [265/320], Step [100/391] Loss: 0.7698 LR: 0.0000
# Epoch [265/320], Step [200/391] Loss: 0.5738 LR: 0.0000
# Epoch [265/320], Step [300/391] Loss: 0.6613 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [266/320], Step [100/391] Loss: 0.7606 LR: 0.0000
# Epoch [266/320], Step [200/391] Loss: 0.7661 LR: 0.0000
# Epoch [266/320], Step [300/391] Loss: 0.8462 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [267/320], Step [100/391] Loss: 0.6637 LR: 0.0000
# Epoch [267/320], Step [200/391] Loss: 0.7285 LR: 0.0000
# Epoch [267/320], Step [300/391] Loss: 0.7536 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [268/320], Step [100/391] Loss: 0.7975 LR: 0.0000
# Epoch [268/320], Step [200/391] Loss: 0.6879 LR: 0.0000
# Epoch [268/320], Step [300/391] Loss: 0.6780 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [269/320], Step [100/391] Loss: 0.6178 LR: 0.0000
# Epoch [269/320], Step [200/391] Loss: 0.5449 LR: 0.0000
# Epoch [269/320], Step [300/391] Loss: 0.5631 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [270/320], Step [100/391] Loss: 0.6413 LR: 0.0000
# Epoch [270/320], Step [200/391] Loss: 0.6907 LR: 0.0000
# Epoch [270/320], Step [300/391] Loss: 0.6684 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [271/320], Step [100/391] Loss: 0.5434 LR: 0.0000
# Epoch [271/320], Step [200/391] Loss: 0.7357 LR: 0.0000
# Epoch [271/320], Step [300/391] Loss: 0.6013 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [272/320], Step [100/391] Loss: 0.6719 LR: 0.0000
# Epoch [272/320], Step [200/391] Loss: 0.7119 LR: 0.0000
# Epoch [272/320], Step [300/391] Loss: 0.6707 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [273/320], Step [100/391] Loss: 0.5645 LR: 0.0000
# Epoch [273/320], Step [200/391] Loss: 0.5847 LR: 0.0000
# Epoch [273/320], Step [300/391] Loss: 0.8345 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [274/320], Step [100/391] Loss: 0.6904 LR: 0.0000
# Epoch [274/320], Step [200/391] Loss: 0.5458 LR: 0.0000
# Epoch [274/320], Step [300/391] Loss: 0.6921 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [275/320], Step [100/391] Loss: 0.7377 LR: 0.0000
# Epoch [275/320], Step [200/391] Loss: 0.6335 LR: 0.0000
# Epoch [275/320], Step [300/391] Loss: 0.6935 LR: 0.0000
# Accuracy of the network : 72 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [276/320], Step [100/391] Loss: 0.6134 LR: 0.0000
# Epoch [276/320], Step [200/391] Loss: 0.5920 LR: 0.0000
# Epoch [276/320], Step [300/391] Loss: 0.7249 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [277/320], Step [100/391] Loss: 0.6451 LR: 0.0000
# Epoch [277/320], Step [200/391] Loss: 0.7397 LR: 0.0000
# Epoch [277/320], Step [300/391] Loss: 0.7701 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [278/320], Step [100/391] Loss: 0.6756 LR: 0.0000
# Epoch [278/320], Step [200/391] Loss: 0.7500 LR: 0.0000
# Epoch [278/320], Step [300/391] Loss: 0.6392 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [279/320], Step [100/391] Loss: 0.6742 LR: 0.0000
# Epoch [279/320], Step [200/391] Loss: 0.7028 LR: 0.0000
# Epoch [279/320], Step [300/391] Loss: 0.8345 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [280/320], Step [100/391] Loss: 0.5800 LR: 0.0000
# Epoch [280/320], Step [200/391] Loss: 0.8491 LR: 0.0000
# Epoch [280/320], Step [300/391] Loss: 0.6766 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [281/320], Step [100/391] Loss: 0.7232 LR: 0.0000
# Epoch [281/320], Step [200/391] Loss: 0.6953 LR: 0.0000
# Epoch [281/320], Step [300/391] Loss: 0.7628 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [282/320], Step [100/391] Loss: 0.7864 LR: 0.0000
# Epoch [282/320], Step [200/391] Loss: 0.7015 LR: 0.0000
# Epoch [282/320], Step [300/391] Loss: 0.5864 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [283/320], Step [100/391] Loss: 0.6526 LR: 0.0000
# Epoch [283/320], Step [200/391] Loss: 0.8351 LR: 0.0000
# Epoch [283/320], Step [300/391] Loss: 0.9338 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [284/320], Step [100/391] Loss: 0.6504 LR: 0.0000
# Epoch [284/320], Step [200/391] Loss: 0.6346 LR: 0.0000
# Epoch [284/320], Step [300/391] Loss: 0.7801 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [285/320], Step [100/391] Loss: 1.0893 LR: 0.0000
# Epoch [285/320], Step [200/391] Loss: 0.7991 LR: 0.0000
# Epoch [285/320], Step [300/391] Loss: 0.7006 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [286/320], Step [100/391] Loss: 0.7755 LR: 0.0000
# Epoch [286/320], Step [200/391] Loss: 0.8286 LR: 0.0000
# Epoch [286/320], Step [300/391] Loss: 0.7438 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [287/320], Step [100/391] Loss: 0.8099 LR: 0.0000
# Epoch [287/320], Step [200/391] Loss: 0.6628 LR: 0.0000
# Epoch [287/320], Step [300/391] Loss: 0.8598 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [288/320], Step [100/391] Loss: 0.7382 LR: 0.0000
# Epoch [288/320], Step [200/391] Loss: 0.7346 LR: 0.0000
# Epoch [288/320], Step [300/391] Loss: 0.6777 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [289/320], Step [100/391] Loss: 0.5767 LR: 0.0000
# Epoch [289/320], Step [200/391] Loss: 0.8897 LR: 0.0000
# Epoch [289/320], Step [300/391] Loss: 0.7398 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [290/320], Step [100/391] Loss: 0.6888 LR: 0.0000
# Epoch [290/320], Step [200/391] Loss: 0.6346 LR: 0.0000
# Epoch [290/320], Step [300/391] Loss: 0.5294 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [291/320], Step [100/391] Loss: 0.8207 LR: 0.0000
# Epoch [291/320], Step [200/391] Loss: 0.6298 LR: 0.0000
# Epoch [291/320], Step [300/391] Loss: 0.6963 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [292/320], Step [100/391] Loss: 0.7102 LR: 0.0000
# Epoch [292/320], Step [200/391] Loss: 0.7254 LR: 0.0000
# Epoch [292/320], Step [300/391] Loss: 0.6923 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [293/320], Step [100/391] Loss: 0.7365 LR: 0.0000
# Epoch [293/320], Step [200/391] Loss: 0.6553 LR: 0.0000
# Epoch [293/320], Step [300/391] Loss: 0.8827 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [294/320], Step [100/391] Loss: 0.8101 LR: 0.0000
# Epoch [294/320], Step [200/391] Loss: 0.6588 LR: 0.0000
# Epoch [294/320], Step [300/391] Loss: 0.6208 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [295/320], Step [100/391] Loss: 0.6815 LR: 0.0000
# Epoch [295/320], Step [200/391] Loss: 0.6752 LR: 0.0000
# Epoch [295/320], Step [300/391] Loss: 0.7405 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [296/320], Step [100/391] Loss: 0.7433 LR: 0.0000
# Epoch [296/320], Step [200/391] Loss: 0.6158 LR: 0.0000
# Epoch [296/320], Step [300/391] Loss: 0.7442 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [297/320], Step [100/391] Loss: 0.8427 LR: 0.0000
# Epoch [297/320], Step [200/391] Loss: 0.6832 LR: 0.0000
# Epoch [297/320], Step [300/391] Loss: 0.7779 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [298/320], Step [100/391] Loss: 0.6444 LR: 0.0000
# Epoch [298/320], Step [200/391] Loss: 0.6930 LR: 0.0000
# Epoch [298/320], Step [300/391] Loss: 0.9163 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [299/320], Step [100/391] Loss: 0.6340 LR: 0.0000
# Epoch [299/320], Step [200/391] Loss: 0.7879 LR: 0.0000
# Epoch [299/320], Step [300/391] Loss: 0.6609 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [300/320], Step [100/391] Loss: 0.6597 LR: 0.0000
# Epoch [300/320], Step [200/391] Loss: 0.6885 LR: 0.0000
# Epoch [300/320], Step [300/391] Loss: 0.6720 LR: 0.0000
# Accuracy of the network : 73 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [301/320], Step [100/391] Loss: 0.6848 LR: 0.0000
# Epoch [301/320], Step [200/391] Loss: 0.7477 LR: 0.0000
# Epoch [301/320], Step [300/391] Loss: 0.7498 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [302/320], Step [100/391] Loss: 0.5987 LR: 0.0000
# Epoch [302/320], Step [200/391] Loss: 0.7362 LR: 0.0000
# Epoch [302/320], Step [300/391] Loss: 0.6299 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [303/320], Step [100/391] Loss: 0.6568 LR: 0.0000
# Epoch [303/320], Step [200/391] Loss: 0.8533 LR: 0.0000
# Epoch [303/320], Step [300/391] Loss: 0.7145 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [304/320], Step [100/391] Loss: 0.6703 LR: 0.0000
# Epoch [304/320], Step [200/391] Loss: 0.6926 LR: 0.0000
# Epoch [304/320], Step [300/391] Loss: 0.7242 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [305/320], Step [100/391] Loss: 0.7402 LR: 0.0000
# Epoch [305/320], Step [200/391] Loss: 0.6913 LR: 0.0000
# Epoch [305/320], Step [300/391] Loss: 0.7010 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [306/320], Step [100/391] Loss: 0.8588 LR: 0.0000
# Epoch [306/320], Step [200/391] Loss: 0.6908 LR: 0.0000
# Epoch [306/320], Step [300/391] Loss: 0.7065 LR: 0.0000
# Accuracy of the network : 71 %
# Using clean
# Epoch [307/320], Step [100/391] Loss: 0.8331 LR: 0.0000
# Epoch [307/320], Step [200/391] Loss: 0.6330 LR: 0.0000
# Epoch [307/320], Step [300/391] Loss: 0.5367 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [308/320], Step [100/391] Loss: 0.7272 LR: 0.0000
# Epoch [308/320], Step [200/391] Loss: 0.7733 LR: 0.0000
# Epoch [308/320], Step [300/391] Loss: 0.6225 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [309/320], Step [100/391] Loss: 0.7149 LR: 0.0000
# Epoch [309/320], Step [200/391] Loss: 0.6987 LR: 0.0000
# Epoch [309/320], Step [300/391] Loss: 0.7277 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [310/320], Step [100/391] Loss: 0.7574 LR: 0.0000
# Epoch [310/320], Step [200/391] Loss: 0.7275 LR: 0.0000
# Epoch [310/320], Step [300/391] Loss: 0.8819 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [311/320], Step [100/391] Loss: 0.5814 LR: 0.0000
# Epoch [311/320], Step [200/391] Loss: 0.6325 LR: 0.0000
# Epoch [311/320], Step [300/391] Loss: 0.6789 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [312/320], Step [100/391] Loss: 0.7866 LR: 0.0000
# Epoch [312/320], Step [200/391] Loss: 0.8397 LR: 0.0000
# Epoch [312/320], Step [300/391] Loss: 0.7931 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [313/320], Step [100/391] Loss: 0.6533 LR: 0.0000
# Epoch [313/320], Step [200/391] Loss: 0.7426 LR: 0.0000
# Epoch [313/320], Step [300/391] Loss: 0.8434 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [314/320], Step [100/391] Loss: 0.7361 LR: 0.0000
# Epoch [314/320], Step [200/391] Loss: 0.8003 LR: 0.0000
# Epoch [314/320], Step [300/391] Loss: 0.6598 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [315/320], Step [100/391] Loss: 0.6914 LR: 0.0000
# Epoch [315/320], Step [200/391] Loss: 0.8171 LR: 0.0000
# Epoch [315/320], Step [300/391] Loss: 0.6872 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [316/320], Step [100/391] Loss: 0.7460 LR: 0.0000
# Epoch [316/320], Step [200/391] Loss: 0.8061 LR: 0.0000
# Epoch [316/320], Step [300/391] Loss: 0.7227 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [317/320], Step [100/391] Loss: 0.6730 LR: 0.0000
# Epoch [317/320], Step [200/391] Loss: 0.6846 LR: 0.0000
# Epoch [317/320], Step [300/391] Loss: 0.5233 LR: 0.0000
# Accuracy of the network : 71 %
# Using clean
# Epoch [318/320], Step [100/391] Loss: 0.6031 LR: 0.0000
# Epoch [318/320], Step [200/391] Loss: 0.7446 LR: 0.0000
# Epoch [318/320], Step [300/391] Loss: 0.7678 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [319/320], Step [100/391] Loss: 0.7583 LR: 0.0000
# Epoch [319/320], Step [200/391] Loss: 0.7416 LR: 0.0000
# Epoch [319/320], Step [300/391] Loss: 0.6571 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [320/320], Step [100/391] Loss: 0.6425 LR: 0.0000
# Epoch [320/320], Step [200/391] Loss: 0.6729 LR: 0.0000
# Epoch [320/320], Step [300/391] Loss: 0.7303 LR: 0.0000
# Accuracy of the network : 71 %
# Finished Training

# %%
plt.plot(accuracy_plot)
plt.show()

# %%
plt.plot(loss_plot)
plt.show()

# %%
PATH = './cifar_net_5.pth'
torch.save(net.state_dict(), PATH)

# %%
np.save('./acc_5.npy', accuracy_plot)
np.save('./loss_5.npy', loss_plot)

# %%
acc_data = np.load('./acc_5.npy')
plt.plot(acc_data)
plt.show()

# %%
loss_data = np.load('./loss_5.npy')
plt.plot(loss_data)
plt.show()

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: plane is 77.3 %
# Accuracy for class: car   is 83.9 %
# Accuracy for class: bird  is 61.1 %
# Accuracy for class: cat   is 54.7 %
# Accuracy for class: deer  is 67.8 %
# Accuracy for class: dog   is 60.8 %
# Accuracy for class: frog  is 78.6 %
# Accuracy for class: horse is 75.6 %
# Accuracy for class: ship  is 84.1 %
# Accuracy for class: truck is 79.1 %
