# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
FIM_data = np.load('./FIM_plot_2.npy')
plt.plot(FIM_data)
plt.show()

# %%
fim_diff = []
for i in range(220):
    fim_diff.append(FIM_data[i] - FIM_data[i-1])

# %%
plt.plot(fim_diff)
plt.show()
