# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
# Out:
# /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /lib64/libz.so.1: version `ZLIB_1.2.9' not found (required by /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/../../../libpng16.so.16)
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
load_from_chkpt = True # Load from checkpoint in case of resuming training

# %%
transform = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
transform_blur = transforms.Compose([
                                     transforms.Resize((8,8)),
                                     transforms.Resize((32,32),interpolation=InterpolationMode.BILINEAR),
                                     transforms.RandomCrop(32, padding=4),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

# CIFAR 10 Dataset
train_dataset_clean = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform,
                                             download=True)

train_dataset_blur = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform_blur,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='./data/',
                                            train=False, 
                                            transform=transform)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128

train_loader_clean = torch.utils.data.DataLoader(dataset=train_dataset_clean,
                                           batch_size=batch_size, 
                                           shuffle=True)

train_loader_blur = torch.utils.data.DataLoader(dataset=train_dataset_blur,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
# def imshow(img, fig_title):
#     # img = img / 2 + 0.5
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg.squeeze()))
#     plt.title(fig_title)
#     plt.show()
    


# # get some random training images and show
# dataiter_blur = iter(train_loader_blur)
# images_blur, labels_blur = dataiter_blur.next()
# imshow(torchvision.utils.make_grid(images_blur), "Blurred images")
# # print(' '.join(f'{classes[labels_blur[j]]:5s}' for j in range(batch_size)))

# dataiter_clean = iter(train_loader_clean)
# images_clean, labels_clean = dataiter_clean.next()
# imshow(torchvision.utils.make_grid(images_clean), "Clean images")
# # print(' '.join(f'{classes[labels_clean[j]]:5s}' for j in range(batch_size)))

# %%
class AllCNNNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.dp0 = nn.Dropout2d(p = 0.2)
    self.conv1 = nn.Conv2d(3, 96, 3, padding=1)
    self.conv2 = nn.Conv2d(96, 96, 3, padding=1)
    self.conv3 = nn.Conv2d(96, 192, 3, stride=2, padding=1)
    self.dp1 = nn.Dropout2d(p = 0.5)
    self.conv4 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv5 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv6 = nn.Conv2d(192, 192, 3, stride=2, padding=1)
    self.dp2 = nn.Dropout2d(p = 0.5)
    self.conv7 = nn.Conv2d(192, 192, 3, padding=0)
    self.conv8 = nn.Conv2d(192, 192, 1)
    self.conv9 = nn.Conv2d(192, 10, 1)
    self.avg = nn.AvgPool2d(6)

    nn.init.xavier_normal_(self.conv1.weight)
    nn.init.xavier_normal_(self.conv2.weight)
    nn.init.xavier_normal_(self.conv3.weight)
    nn.init.xavier_normal_(self.conv4.weight)
    nn.init.xavier_normal_(self.conv5.weight)
    nn.init.xavier_normal_(self.conv6.weight)
    nn.init.xavier_normal_(self.conv7.weight)
    nn.init.xavier_normal_(self.conv8.weight)
    nn.init.xavier_normal_(self.conv9.weight)

  def forward(self, x):
    x = self.dp0(x)
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = self.dp1(x)
    x = F.relu(self.conv4(x))
    x = F.relu(self.conv5(x))
    x = F.relu(self.conv6(x))
    x = self.dp2(x)
    x = F.relu(self.conv7(x))
    x = F.relu(self.conv8(x))
    x = F.relu(self.conv9(x))
    x = self.avg(x)
    x = torch.squeeze(x)
    # x = F.softmax(x, dim=0)
    return x

net = AllCNNNet().to(device)

# %%
# class AllCNNNet(nn.Module):
#   def __init__(self):
#     super().__init__()
#     self.conv1 = nn.Conv2d(3, 6, 5)
#     self.pool = nn.MaxPool2d(2, 2)
#     self.conv2 = nn.Conv2d(6, 16, 5)
#     self.fc1 = nn.Linear(16*5*5, 120)
#     self.fc2 = nn.Linear(120, 84)
#     self.fc3 = nn.Linear(84, 10)

#   def forward(self, x):
#     x = self.pool(F.relu(self.conv1(x)))
#     x = self.pool(F.relu(self.conv2(x)))
#     x = torch.flatten(x, 1)
#     x = F.relu(self.fc1(x))
#     x = F.relu(self.fc2(x))
#     x = self.fc3(x)
#     return x

# net = AllCNNNet().to(device)

# %%
# Hyper-parameters
num_epochs_blur = 120
num_epochs_clean = 160
learning_rate = 0.05

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)
# optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# from torchsummary import summary

# summary(net, (3, 32, 32))

# %%
# For updating learning rate
def update_lr(optimizer, lr):    
#     print ("Updating LR")
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
num_epochs = num_epochs_blur + num_epochs_clean
total_step = len(train_loader_clean)
curr_lr = learning_rate
loss_plot = []
accuracy_plot = []
epoch_chkpt = 0

if(load_from_chkpt):
  # Load model from checkpoint
  path_chkpt = "./chkpt_3/model.pt"
  loss_plot_chkpt = "./chkpt_3/loss_plot.npy"
  acc_plot_chkpt = "./chkpt_3/acc_plot.npy"
  model = net
#   optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)

  checkpoint = torch.load(path_chkpt)
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch_chkpt = checkpoint['epoch']
  loss = checkpoint['loss']
  curr_lr = checkpoint['curr_lr']
  loss_plot = np.append(loss_plot, np.load(loss_plot_chkpt))
  accuracy_plot = np.append(accuracy_plot, np.load(acc_plot_chkpt))

  model.train()
  print("!!!Loaded from checkpoint!!! Epoch:{} Loss:{} curr_lr:{}".format(epoch_chkpt, loss, curr_lr))

for epoch in range(epoch_chkpt, num_epochs):  # loop over the dataset multiple times
  if epoch < num_epochs_blur:
    train_loader = train_loader_blur
    print("Using blur")
  else:
    train_loader = train_loader_clean
    print("Using clean")

  # running_loss = 0.0
  for i, (inputs, labels) in enumerate(train_loader):
      inputs = inputs.to(device)
      labels = labels.to(device)

      # forward + backward + optimize
      outputs = net(inputs)
      loss = criterion(outputs, labels)

      # zero the parameter gradients
      optimizer.zero_grad()
      loss.backward()


      optimizer.step()
      loss_plot = np.append(loss_plot, loss.item())

      if (i+1) % 100 == 0:
        print ("Epoch [{}/{}], Step [{}/{}] Loss: {:.4f} LR: {:.4f}"
                .format(epoch+1, num_epochs, i+1, total_step, loss.item(), curr_lr))

  # Decay learning rate
  curr_lr = 0.97 * curr_lr
  update_lr(optimizer, curr_lr)

  correct = 0
  total = 0
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in test_loader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

  accuracy_temp = 100 * correct // total
  print(f'Accuracy of the network : {accuracy_temp} %')
  accuracy_plot = np.append(accuracy_plot, accuracy_temp)

  if (epoch+1)==2 or (epoch+1)%25==0:
    # Save model checkpoint
    epoch_chkpt = epoch+1
    path_chkpt = "./chkpt_3/model.pt"
    loss_plot_chkpt = './chkpt_3/loss_plot.npy'
    acc_plot_chkpt = './chkpt_3/acc_plot.npy'
    loss_chkpt = loss.item()

    torch.save({
                'epoch': epoch_chkpt,
                'model_state_dict': net.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss_chkpt,
                'curr_lr': curr_lr,
                }, path_chkpt)
    np.save(loss_plot_chkpt, loss_plot)
    np.save(acc_plot_chkpt, accuracy_plot)
    print('!!!Checkpoint saved!!!')

print('Finished Training')
# Out:
# !!!Loaded from checkpoint!!! Epoch:200 Loss:0.6653290390968323 curr_lr:0.0001130620504997884
# Using clean
# Epoch [201/280], Step [100/391] Loss: 0.4973 LR: 0.0001
# Epoch [201/280], Step [200/391] Loss: 0.8197 LR: 0.0001
# Epoch [201/280], Step [300/391] Loss: 0.7253 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [202/280], Step [100/391] Loss: 0.6471 LR: 0.0001
# Epoch [202/280], Step [200/391] Loss: 0.5897 LR: 0.0001
# Epoch [202/280], Step [300/391] Loss: 0.6301 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [203/280], Step [100/391] Loss: 0.6244 LR: 0.0001
# Epoch [203/280], Step [200/391] Loss: 0.6425 LR: 0.0001
# Epoch [203/280], Step [300/391] Loss: 0.7792 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [204/280], Step [100/391] Loss: 0.8736 LR: 0.0001
# Epoch [204/280], Step [200/391] Loss: 0.5923 LR: 0.0001
# Epoch [204/280], Step [300/391] Loss: 0.6265 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [205/280], Step [100/391] Loss: 0.6910 LR: 0.0001
# Epoch [205/280], Step [200/391] Loss: 0.5442 LR: 0.0001
# Epoch [205/280], Step [300/391] Loss: 0.7054 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [206/280], Step [100/391] Loss: 0.6978 LR: 0.0001
# Epoch [206/280], Step [200/391] Loss: 0.7272 LR: 0.0001
# Epoch [206/280], Step [300/391] Loss: 0.5257 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [207/280], Step [100/391] Loss: 0.6311 LR: 0.0001
# Epoch [207/280], Step [200/391] Loss: 0.7525 LR: 0.0001
# Epoch [207/280], Step [300/391] Loss: 0.6032 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [208/280], Step [100/391] Loss: 0.8033 LR: 0.0001
# Epoch [208/280], Step [200/391] Loss: 0.7092 LR: 0.0001
# Epoch [208/280], Step [300/391] Loss: 0.7864 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [209/280], Step [100/391] Loss: 0.4819 LR: 0.0001
# Epoch [209/280], Step [200/391] Loss: 0.5538 LR: 0.0001
# Epoch [209/280], Step [300/391] Loss: 0.7102 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [210/280], Step [100/391] Loss: 0.6613 LR: 0.0001
# Epoch [210/280], Step [200/391] Loss: 0.6316 LR: 0.0001
# Epoch [210/280], Step [300/391] Loss: 0.5975 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [211/280], Step [100/391] Loss: 0.7020 LR: 0.0001
# Epoch [211/280], Step [200/391] Loss: 0.6834 LR: 0.0001
# Epoch [211/280], Step [300/391] Loss: 0.5443 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [212/280], Step [100/391] Loss: 0.6641 LR: 0.0001
# Epoch [212/280], Step [200/391] Loss: 0.7521 LR: 0.0001
# Epoch [212/280], Step [300/391] Loss: 0.6706 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [213/280], Step [100/391] Loss: 0.7589 LR: 0.0001
# Epoch [213/280], Step [200/391] Loss: 0.6397 LR: 0.0001
# Epoch [213/280], Step [300/391] Loss: 0.7062 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [214/280], Step [100/391] Loss: 0.5719 LR: 0.0001
# Epoch [214/280], Step [200/391] Loss: 0.8408 LR: 0.0001
# Epoch [214/280], Step [300/391] Loss: 0.5740 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [215/280], Step [100/391] Loss: 0.7399 LR: 0.0001
# Epoch [215/280], Step [200/391] Loss: 0.7066 LR: 0.0001
# Epoch [215/280], Step [300/391] Loss: 0.7277 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [216/280], Step [100/391] Loss: 0.6607 LR: 0.0001
# Epoch [216/280], Step [200/391] Loss: 0.5191 LR: 0.0001
# Epoch [216/280], Step [300/391] Loss: 0.5491 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [217/280], Step [100/391] Loss: 0.6339 LR: 0.0001
# Epoch [217/280], Step [200/391] Loss: 0.4479 LR: 0.0001
# Epoch [217/280], Step [300/391] Loss: 0.6476 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [218/280], Step [100/391] Loss: 0.6472 LR: 0.0001
# Epoch [218/280], Step [200/391] Loss: 0.7187 LR: 0.0001
# Epoch [218/280], Step [300/391] Loss: 0.6105 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [219/280], Step [100/391] Loss: 0.5942 LR: 0.0001
# Epoch [219/280], Step [200/391] Loss: 0.7331 LR: 0.0001
# Epoch [219/280], Step [300/391] Loss: 0.6826 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [220/280], Step [100/391] Loss: 0.6007 LR: 0.0001
# Epoch [220/280], Step [200/391] Loss: 0.6683 LR: 0.0001
# Epoch [220/280], Step [300/391] Loss: 0.6789 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [221/280], Step [100/391] Loss: 0.6912 LR: 0.0001
# Epoch [221/280], Step [200/391] Loss: 0.6204 LR: 0.0001
# Epoch [221/280], Step [300/391] Loss: 0.7329 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [222/280], Step [100/391] Loss: 0.6692 LR: 0.0001
# Epoch [222/280], Step [200/391] Loss: 0.5343 LR: 0.0001
# Epoch [222/280], Step [300/391] Loss: 0.8593 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [223/280], Step [100/391] Loss: 0.4862 LR: 0.0001
# Epoch [223/280], Step [200/391] Loss: 0.7226 LR: 0.0001
# Epoch [223/280], Step [300/391] Loss: 0.5962 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [224/280], Step [100/391] Loss: 0.7516 LR: 0.0001
# Epoch [224/280], Step [200/391] Loss: 0.6209 LR: 0.0001
# Epoch [224/280], Step [300/391] Loss: 0.5792 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [225/280], Step [100/391] Loss: 0.5380 LR: 0.0001
# Epoch [225/280], Step [200/391] Loss: 0.6198 LR: 0.0001
# Epoch [225/280], Step [300/391] Loss: 0.8574 LR: 0.0001
# Accuracy of the network : 74 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [226/280], Step [100/391] Loss: 0.5876 LR: 0.0001
# Epoch [226/280], Step [200/391] Loss: 0.6285 LR: 0.0001
# Epoch [226/280], Step [300/391] Loss: 0.7026 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [227/280], Step [100/391] Loss: 0.6514 LR: 0.0001
# Epoch [227/280], Step [200/391] Loss: 0.6372 LR: 0.0001
# Epoch [227/280], Step [300/391] Loss: 0.5978 LR: 0.0001
# Accuracy of the network : 74 %
# Using clean
# Epoch [228/280], Step [100/391] Loss: 0.7129 LR: 0.0000
# Epoch [228/280], Step [200/391] Loss: 0.6358 LR: 0.0000
# Epoch [228/280], Step [300/391] Loss: 0.6276 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [229/280], Step [100/391] Loss: 0.7429 LR: 0.0000
# Epoch [229/280], Step [200/391] Loss: 0.8015 LR: 0.0000
# Epoch [229/280], Step [300/391] Loss: 0.6194 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [230/280], Step [100/391] Loss: 0.6320 LR: 0.0000
# Epoch [230/280], Step [200/391] Loss: 0.6352 LR: 0.0000
# Epoch [230/280], Step [300/391] Loss: 0.6955 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [231/280], Step [100/391] Loss: 0.6229 LR: 0.0000
# Epoch [231/280], Step [200/391] Loss: 0.7872 LR: 0.0000
# Epoch [231/280], Step [300/391] Loss: 0.6169 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [232/280], Step [100/391] Loss: 0.5566 LR: 0.0000
# Epoch [232/280], Step [200/391] Loss: 0.6233 LR: 0.0000
# Epoch [232/280], Step [300/391] Loss: 0.6700 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [233/280], Step [100/391] Loss: 0.7422 LR: 0.0000
# Epoch [233/280], Step [200/391] Loss: 0.6205 LR: 0.0000
# Epoch [233/280], Step [300/391] Loss: 0.6050 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [234/280], Step [100/391] Loss: 0.7746 LR: 0.0000
# Epoch [234/280], Step [200/391] Loss: 0.7128 LR: 0.0000
# Epoch [234/280], Step [300/391] Loss: 0.5153 LR: 0.0000
# Accuracy of the network : 75 %
# Using clean
# Epoch [235/280], Step [100/391] Loss: 0.7986 LR: 0.0000
# Epoch [235/280], Step [200/391] Loss: 0.5871 LR: 0.0000
# Epoch [235/280], Step [300/391] Loss: 0.6246 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [236/280], Step [100/391] Loss: 0.5629 LR: 0.0000
# Epoch [236/280], Step [200/391] Loss: 0.6680 LR: 0.0000
# Epoch [236/280], Step [300/391] Loss: 0.7125 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [237/280], Step [100/391] Loss: 0.6621 LR: 0.0000
# Epoch [237/280], Step [200/391] Loss: 0.7211 LR: 0.0000
# Epoch [237/280], Step [300/391] Loss: 0.6249 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [238/280], Step [100/391] Loss: 0.5542 LR: 0.0000
# Epoch [238/280], Step [200/391] Loss: 0.6487 LR: 0.0000
# Epoch [238/280], Step [300/391] Loss: 0.6805 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [239/280], Step [100/391] Loss: 0.6968 LR: 0.0000
# Epoch [239/280], Step [200/391] Loss: 0.6096 LR: 0.0000
# Epoch [239/280], Step [300/391] Loss: 0.6801 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [240/280], Step [100/391] Loss: 0.5359 LR: 0.0000
# Epoch [240/280], Step [200/391] Loss: 0.6948 LR: 0.0000
# Epoch [240/280], Step [300/391] Loss: 0.5770 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [241/280], Step [100/391] Loss: 0.6234 LR: 0.0000
# Epoch [241/280], Step [200/391] Loss: 0.5610 LR: 0.0000
# Epoch [241/280], Step [300/391] Loss: 0.7951 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [242/280], Step [100/391] Loss: 0.6688 LR: 0.0000
# Epoch [242/280], Step [200/391] Loss: 0.6473 LR: 0.0000
# Epoch [242/280], Step [300/391] Loss: 0.4937 LR: 0.0000
# Accuracy of the network : 75 %
# Using clean
# Epoch [243/280], Step [100/391] Loss: 0.5470 LR: 0.0000
# Epoch [243/280], Step [200/391] Loss: 0.6732 LR: 0.0000
# Epoch [243/280], Step [300/391] Loss: 0.6470 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [244/280], Step [100/391] Loss: 0.5789 LR: 0.0000
# Epoch [244/280], Step [200/391] Loss: 0.5735 LR: 0.0000
# Epoch [244/280], Step [300/391] Loss: 0.6742 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [245/280], Step [100/391] Loss: 0.6074 LR: 0.0000
# Epoch [245/280], Step [200/391] Loss: 0.5995 LR: 0.0000
# Epoch [245/280], Step [300/391] Loss: 0.5426 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [246/280], Step [100/391] Loss: 0.7081 LR: 0.0000
# Epoch [246/280], Step [200/391] Loss: 0.6300 LR: 0.0000
# Epoch [246/280], Step [300/391] Loss: 0.6487 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [247/280], Step [100/391] Loss: 0.5849 LR: 0.0000
# Epoch [247/280], Step [200/391] Loss: 0.6315 LR: 0.0000
# Epoch [247/280], Step [300/391] Loss: 0.6514 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [248/280], Step [100/391] Loss: 0.6708 LR: 0.0000
# Epoch [248/280], Step [200/391] Loss: 0.4950 LR: 0.0000
# Epoch [248/280], Step [300/391] Loss: 0.6619 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [249/280], Step [100/391] Loss: 0.6058 LR: 0.0000
# Epoch [249/280], Step [200/391] Loss: 0.8090 LR: 0.0000
# Epoch [249/280], Step [300/391] Loss: 0.6009 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [250/280], Step [100/391] Loss: 0.6249 LR: 0.0000
# Epoch [250/280], Step [200/391] Loss: 0.6822 LR: 0.0000
# Epoch [250/280], Step [300/391] Loss: 0.6152 LR: 0.0000
# Accuracy of the network : 74 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [251/280], Step [100/391] Loss: 0.8287 LR: 0.0000
# Epoch [251/280], Step [200/391] Loss: 0.6274 LR: 0.0000
# Epoch [251/280], Step [300/391] Loss: 0.6687 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [252/280], Step [100/391] Loss: 0.5539 LR: 0.0000
# Epoch [252/280], Step [200/391] Loss: 0.6389 LR: 0.0000
# Epoch [252/280], Step [300/391] Loss: 0.6189 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [253/280], Step [100/391] Loss: 0.6299 LR: 0.0000
# Epoch [253/280], Step [200/391] Loss: 0.6612 LR: 0.0000
# Epoch [253/280], Step [300/391] Loss: 0.6692 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [254/280], Step [100/391] Loss: 0.6640 LR: 0.0000
# Epoch [254/280], Step [200/391] Loss: 0.5912 LR: 0.0000
# Epoch [254/280], Step [300/391] Loss: 0.6724 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [255/280], Step [100/391] Loss: 0.5686 LR: 0.0000
# Epoch [255/280], Step [200/391] Loss: 0.6353 LR: 0.0000
# Epoch [255/280], Step [300/391] Loss: 0.7422 LR: 0.0000
# Accuracy of the network : 75 %
# Using clean
# Epoch [256/280], Step [100/391] Loss: 0.7137 LR: 0.0000
# Epoch [256/280], Step [200/391] Loss: 0.7173 LR: 0.0000
# Epoch [256/280], Step [300/391] Loss: 0.7539 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [257/280], Step [100/391] Loss: 0.7057 LR: 0.0000
# Epoch [257/280], Step [200/391] Loss: 0.6364 LR: 0.0000
# Epoch [257/280], Step [300/391] Loss: 0.5889 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [258/280], Step [100/391] Loss: 0.5280 LR: 0.0000
# Epoch [258/280], Step [200/391] Loss: 0.5887 LR: 0.0000
# Epoch [258/280], Step [300/391] Loss: 0.6896 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [259/280], Step [100/391] Loss: 0.6576 LR: 0.0000
# Epoch [259/280], Step [200/391] Loss: 0.6731 LR: 0.0000
# Epoch [259/280], Step [300/391] Loss: 0.5713 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [260/280], Step [100/391] Loss: 0.6645 LR: 0.0000
# Epoch [260/280], Step [200/391] Loss: 0.7078 LR: 0.0000
# Epoch [260/280], Step [300/391] Loss: 0.6613 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [261/280], Step [100/391] Loss: 0.5850 LR: 0.0000
# Epoch [261/280], Step [200/391] Loss: 0.6059 LR: 0.0000
# Epoch [261/280], Step [300/391] Loss: 0.6917 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [262/280], Step [100/391] Loss: 0.8013 LR: 0.0000
# Epoch [262/280], Step [200/391] Loss: 0.5420 LR: 0.0000
# Epoch [262/280], Step [300/391] Loss: 0.5206 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [263/280], Step [100/391] Loss: 0.5170 LR: 0.0000
# Epoch [263/280], Step [200/391] Loss: 0.7010 LR: 0.0000
# Epoch [263/280], Step [300/391] Loss: 0.7182 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [264/280], Step [100/391] Loss: 0.5933 LR: 0.0000
# Epoch [264/280], Step [200/391] Loss: 0.6354 LR: 0.0000
# Epoch [264/280], Step [300/391] Loss: 0.7002 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [265/280], Step [100/391] Loss: 0.5271 LR: 0.0000
# Epoch [265/280], Step [200/391] Loss: 0.4673 LR: 0.0000
# Epoch [265/280], Step [300/391] Loss: 0.5671 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [266/280], Step [100/391] Loss: 0.5935 LR: 0.0000
# Epoch [266/280], Step [200/391] Loss: 0.6411 LR: 0.0000
# Epoch [266/280], Step [300/391] Loss: 0.5633 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [267/280], Step [100/391] Loss: 0.4761 LR: 0.0000
# Epoch [267/280], Step [200/391] Loss: 0.5431 LR: 0.0000
# Epoch [267/280], Step [300/391] Loss: 0.7037 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [268/280], Step [100/391] Loss: 0.5738 LR: 0.0000
# Epoch [268/280], Step [200/391] Loss: 0.5215 LR: 0.0000
# Epoch [268/280], Step [300/391] Loss: 0.6549 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [269/280], Step [100/391] Loss: 0.6995 LR: 0.0000
# Epoch [269/280], Step [200/391] Loss: 0.7826 LR: 0.0000
# Epoch [269/280], Step [300/391] Loss: 0.6562 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [270/280], Step [100/391] Loss: 0.7224 LR: 0.0000
# Epoch [270/280], Step [200/391] Loss: 0.6612 LR: 0.0000
# Epoch [270/280], Step [300/391] Loss: 0.5975 LR: 0.0000
# Accuracy of the network : 75 %
# Using clean
# Epoch [271/280], Step [100/391] Loss: 0.5633 LR: 0.0000
# Epoch [271/280], Step [200/391] Loss: 0.7460 LR: 0.0000
# Epoch [271/280], Step [300/391] Loss: 0.5983 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [272/280], Step [100/391] Loss: 0.7417 LR: 0.0000
# Epoch [272/280], Step [200/391] Loss: 0.6886 LR: 0.0000
# Epoch [272/280], Step [300/391] Loss: 0.5749 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [273/280], Step [100/391] Loss: 0.8220 LR: 0.0000
# Epoch [273/280], Step [200/391] Loss: 0.5847 LR: 0.0000
# Epoch [273/280], Step [300/391] Loss: 0.6188 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [274/280], Step [100/391] Loss: 0.7851 LR: 0.0000
# Epoch [274/280], Step [200/391] Loss: 0.7021 LR: 0.0000
# Epoch [274/280], Step [300/391] Loss: 0.6137 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [275/280], Step [100/391] Loss: 0.6102 LR: 0.0000
# Epoch [275/280], Step [200/391] Loss: 0.7735 LR: 0.0000
# Epoch [275/280], Step [300/391] Loss: 0.8746 LR: 0.0000
# Accuracy of the network : 74 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [276/280], Step [100/391] Loss: 0.6748 LR: 0.0000
# Epoch [276/280], Step [200/391] Loss: 0.7294 LR: 0.0000
# Epoch [276/280], Step [300/391] Loss: 0.6496 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [277/280], Step [100/391] Loss: 0.7412 LR: 0.0000
# Epoch [277/280], Step [200/391] Loss: 0.4705 LR: 0.0000
# Epoch [277/280], Step [300/391] Loss: 0.5546 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [278/280], Step [100/391] Loss: 0.5581 LR: 0.0000
# Epoch [278/280], Step [200/391] Loss: 0.6368 LR: 0.0000
# Epoch [278/280], Step [300/391] Loss: 0.6121 LR: 0.0000
# Accuracy of the network : 74 %
# Using clean
# Epoch [279/280], Step [100/391] Loss: 0.5569 LR: 0.0000
# Epoch [279/280], Step [200/391] Loss: 0.6607 LR: 0.0000
# Epoch [279/280], Step [300/391] Loss: 0.7462 LR: 0.0000

# %%
plt.plot(accuracy_plot)
plt.show()

# %%
plt.plot(loss_plot)
plt.show()

# %%
PATH = './cifar_net_3.pth'
torch.save(net.state_dict(), PATH)

# %%
np.save('./acc_3.npy', accuracy_plot)
np.save('./loss_3.npy', loss_plot)

# %%
acc_data = np.load('./acc_3.npy')
plt.plot(acc_data)
plt.show()

# %%
loss_data = np.load('./loss_3.npy')
plt.plot(loss_data)
plt.show()

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
