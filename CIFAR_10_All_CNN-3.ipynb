# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
# Out:
# /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /lib64/libz.so.1: version `ZLIB_1.2.9' not found (required by /storage/home/hcocice1/anair319/.conda/envs/sp/lib/python3.9/site-packages/torchvision/../../../libpng16.so.16)
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
load_from_chkpt = True # Load from checkpoint in case of resuming training

# %%
transform = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
transform_blur = transforms.Compose([
                                     transforms.Resize((8,8)),
                                     transforms.Resize((32,32),interpolation=InterpolationMode.BILINEAR),
                                     transforms.RandomCrop(32, padding=4),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

# CIFAR 10 Dataset
train_dataset_clean = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform,
                                             download=True)

train_dataset_blur = torchvision.datasets.CIFAR10(root='./data/',
                                             train=True, 
                                             transform=transform_blur,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='./data/',
                                            train=False, 
                                            transform=transform)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128

train_loader_clean = torch.utils.data.DataLoader(dataset=train_dataset_clean,
                                           batch_size=batch_size, 
                                           shuffle=True)

train_loader_blur = torch.utils.data.DataLoader(dataset=train_dataset_blur,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
# def imshow(img, fig_title):
#     # img = img / 2 + 0.5
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg.squeeze()))
#     plt.title(fig_title)
#     plt.show()
    


# # get some random training images and show
# dataiter_blur = iter(train_loader_blur)
# images_blur, labels_blur = dataiter_blur.next()
# imshow(torchvision.utils.make_grid(images_blur), "Blurred images")
# # print(' '.join(f'{classes[labels_blur[j]]:5s}' for j in range(batch_size)))

# dataiter_clean = iter(train_loader_clean)
# images_clean, labels_clean = dataiter_clean.next()
# imshow(torchvision.utils.make_grid(images_clean), "Clean images")
# # print(' '.join(f'{classes[labels_clean[j]]:5s}' for j in range(batch_size)))

# %%
class AllCNNNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.dp0 = nn.Dropout2d(p = 0.2)
    self.conv1 = nn.Conv2d(3, 96, 3, padding=1)
    self.conv2 = nn.Conv2d(96, 96, 3, padding=1)
    self.conv3 = nn.Conv2d(96, 192, 3, stride=2, padding=1)
    self.dp1 = nn.Dropout2d(p = 0.5)
    self.conv4 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv5 = nn.Conv2d(192, 192, 3, padding=1)
    self.conv6 = nn.Conv2d(192, 192, 3, stride=2, padding=1)
    self.dp2 = nn.Dropout2d(p = 0.5)
    self.conv7 = nn.Conv2d(192, 192, 3, padding=0)
    self.conv8 = nn.Conv2d(192, 192, 1)
    self.conv9 = nn.Conv2d(192, 10, 1)
    self.avg = nn.AvgPool2d(6)

    nn.init.xavier_normal_(self.conv1.weight)
    nn.init.xavier_normal_(self.conv2.weight)
    nn.init.xavier_normal_(self.conv3.weight)
    nn.init.xavier_normal_(self.conv4.weight)
    nn.init.xavier_normal_(self.conv5.weight)
    nn.init.xavier_normal_(self.conv6.weight)
    nn.init.xavier_normal_(self.conv7.weight)
    nn.init.xavier_normal_(self.conv8.weight)
    nn.init.xavier_normal_(self.conv9.weight)

  def forward(self, x):
    x = self.dp0(x)
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = self.dp1(x)
    x = F.relu(self.conv4(x))
    x = F.relu(self.conv5(x))
    x = F.relu(self.conv6(x))
    x = self.dp2(x)
    x = F.relu(self.conv7(x))
    x = F.relu(self.conv8(x))
    x = F.relu(self.conv9(x))
    x = self.avg(x)
    x = torch.squeeze(x)
    # x = F.softmax(x, dim=0)
    return x

net = AllCNNNet().to(device)

# %%
# class AllCNNNet(nn.Module):
#   def __init__(self):
#     super().__init__()
#     self.conv1 = nn.Conv2d(3, 6, 5)
#     self.pool = nn.MaxPool2d(2, 2)
#     self.conv2 = nn.Conv2d(6, 16, 5)
#     self.fc1 = nn.Linear(16*5*5, 120)
#     self.fc2 = nn.Linear(120, 84)
#     self.fc3 = nn.Linear(84, 10)

#   def forward(self, x):
#     x = self.pool(F.relu(self.conv1(x)))
#     x = self.pool(F.relu(self.conv2(x)))
#     x = torch.flatten(x, 1)
#     x = F.relu(self.fc1(x))
#     x = F.relu(self.fc2(x))
#     x = self.fc3(x)
#     return x

# net = AllCNNNet().to(device)

# %%
# Hyper-parameters
num_epochs_blur = 140
num_epochs_clean = 160
learning_rate = 0.05

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)
# optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# from torchsummary import summary

# summary(net, (3, 32, 32))

# %%
# For updating learning rate
def update_lr(optimizer, lr):    
#     print ("Updating LR")
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
num_epochs = num_epochs_blur + num_epochs_clean
total_step = len(train_loader_clean)
curr_lr = learning_rate
loss_plot = []
accuracy_plot = []
epoch_chkpt = 0

if(load_from_chkpt):
  # Load model from checkpoint
  path_chkpt = "./chkpt_4/model.pt"
  loss_plot_chkpt = "./chkpt_4/loss_plot.npy"
  acc_plot_chkpt = "./chkpt_4/acc_plot.npy"
  model = net
#   optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, weight_decay=0.001, momentum=0.9, nesterov=True)

  checkpoint = torch.load(path_chkpt)
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch_chkpt = checkpoint['epoch']
  loss = checkpoint['loss']
  curr_lr = checkpoint['curr_lr']
  loss_plot = np.append(loss_plot, np.load(loss_plot_chkpt))
  accuracy_plot = np.append(accuracy_plot, np.load(acc_plot_chkpt))

  model.train()
  print("!!!Loaded from checkpoint!!! Epoch:{} Loss:{} curr_lr:{}".format(epoch_chkpt, loss, curr_lr))

for epoch in range(epoch_chkpt, num_epochs):  # loop over the dataset multiple times
  if epoch < num_epochs_blur:
    train_loader = train_loader_blur
    print("Using blur")
  else:
    train_loader = train_loader_clean
    print("Using clean")

  # running_loss = 0.0
  for i, (inputs, labels) in enumerate(train_loader):
      inputs = inputs.to(device)
      labels = labels.to(device)

      # forward + backward + optimize
      outputs = net(inputs)
      loss = criterion(outputs, labels)

      # zero the parameter gradients
      optimizer.zero_grad()
      loss.backward()


      optimizer.step()
      loss_plot = np.append(loss_plot, loss.item())

      if (i+1) % 100 == 0:
        print ("Epoch [{}/{}], Step [{}/{}] Loss: {:.4f} LR: {:.4f}"
                .format(epoch+1, num_epochs, i+1, total_step, loss.item(), curr_lr))

  # Decay learning rate
  curr_lr = 0.97 * curr_lr
  update_lr(optimizer, curr_lr)

  correct = 0
  total = 0
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in test_loader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

  accuracy_temp = 100 * correct // total
  print(f'Accuracy of the network : {accuracy_temp} %')
  accuracy_plot = np.append(accuracy_plot, accuracy_temp)

  if (epoch+1)==2 or (epoch+1)%25==0:
    # Save model checkpoint
    epoch_chkpt = epoch+1
    path_chkpt = "./chkpt_4/model.pt"
    loss_plot_chkpt = './chkpt_4/loss_plot.npy'
    acc_plot_chkpt = './chkpt_4/acc_plot.npy'
    loss_chkpt = loss.item()

    torch.save({
                'epoch': epoch_chkpt,
                'model_state_dict': net.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss_chkpt,
                'curr_lr': curr_lr,
                }, path_chkpt)
    np.save(loss_plot_chkpt, loss_plot)
    np.save(acc_plot_chkpt, accuracy_plot)
    print('!!!Checkpoint saved!!!')

print('Finished Training')
# Out:
# !!!Loaded from checkpoint!!! Epoch:200 Loss:0.8354216814041138 curr_lr:0.0001130620504997884
# Using clean
# Epoch [201/300], Step [100/391] Loss: 0.6649 LR: 0.0001
# Epoch [201/300], Step [200/391] Loss: 0.6683 LR: 0.0001
# Epoch [201/300], Step [300/391] Loss: 0.7370 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [202/300], Step [100/391] Loss: 0.7509 LR: 0.0001
# Epoch [202/300], Step [200/391] Loss: 0.6853 LR: 0.0001
# Epoch [202/300], Step [300/391] Loss: 0.6699 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [203/300], Step [100/391] Loss: 0.5749 LR: 0.0001
# Epoch [203/300], Step [200/391] Loss: 0.6290 LR: 0.0001
# Epoch [203/300], Step [300/391] Loss: 0.8179 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [204/300], Step [100/391] Loss: 0.6740 LR: 0.0001
# Epoch [204/300], Step [200/391] Loss: 0.6973 LR: 0.0001
# Epoch [204/300], Step [300/391] Loss: 0.5866 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [205/300], Step [100/391] Loss: 0.8352 LR: 0.0001
# Epoch [205/300], Step [200/391] Loss: 0.6626 LR: 0.0001
# Epoch [205/300], Step [300/391] Loss: 0.7556 LR: 0.0001
# Accuracy of the network : 71 %
# Using clean
# Epoch [206/300], Step [100/391] Loss: 0.6167 LR: 0.0001
# Epoch [206/300], Step [200/391] Loss: 0.7799 LR: 0.0001
# Epoch [206/300], Step [300/391] Loss: 0.6681 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [207/300], Step [100/391] Loss: 0.6911 LR: 0.0001
# Epoch [207/300], Step [200/391] Loss: 0.7662 LR: 0.0001
# Epoch [207/300], Step [300/391] Loss: 0.7259 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [208/300], Step [100/391] Loss: 0.6427 LR: 0.0001
# Epoch [208/300], Step [200/391] Loss: 0.6402 LR: 0.0001
# Epoch [208/300], Step [300/391] Loss: 0.7631 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [209/300], Step [100/391] Loss: 0.9645 LR: 0.0001
# Epoch [209/300], Step [200/391] Loss: 0.8619 LR: 0.0001
# Epoch [209/300], Step [300/391] Loss: 0.6604 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [210/300], Step [100/391] Loss: 0.7334 LR: 0.0001
# Epoch [210/300], Step [200/391] Loss: 0.6506 LR: 0.0001
# Epoch [210/300], Step [300/391] Loss: 0.8224 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [211/300], Step [100/391] Loss: 0.6920 LR: 0.0001
# Epoch [211/300], Step [200/391] Loss: 0.6520 LR: 0.0001
# Epoch [211/300], Step [300/391] Loss: 0.5090 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [212/300], Step [100/391] Loss: 0.7600 LR: 0.0001
# Epoch [212/300], Step [200/391] Loss: 0.6304 LR: 0.0001
# Epoch [212/300], Step [300/391] Loss: 0.5778 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [213/300], Step [100/391] Loss: 0.6772 LR: 0.0001
# Epoch [213/300], Step [200/391] Loss: 0.7117 LR: 0.0001
# Epoch [213/300], Step [300/391] Loss: 0.6778 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [214/300], Step [100/391] Loss: 0.8828 LR: 0.0001
# Epoch [214/300], Step [200/391] Loss: 0.6294 LR: 0.0001
# Epoch [214/300], Step [300/391] Loss: 0.6647 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [215/300], Step [100/391] Loss: 0.6518 LR: 0.0001
# Epoch [215/300], Step [200/391] Loss: 0.6968 LR: 0.0001
# Epoch [215/300], Step [300/391] Loss: 0.5811 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [216/300], Step [100/391] Loss: 0.7035 LR: 0.0001
# Epoch [216/300], Step [200/391] Loss: 0.8065 LR: 0.0001
# Epoch [216/300], Step [300/391] Loss: 0.8138 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [217/300], Step [100/391] Loss: 0.5436 LR: 0.0001
# Epoch [217/300], Step [200/391] Loss: 0.6570 LR: 0.0001
# Epoch [217/300], Step [300/391] Loss: 0.6402 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [218/300], Step [100/391] Loss: 0.6228 LR: 0.0001
# Epoch [218/300], Step [200/391] Loss: 0.7973 LR: 0.0001
# Epoch [218/300], Step [300/391] Loss: 0.5539 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [219/300], Step [100/391] Loss: 0.7117 LR: 0.0001
# Epoch [219/300], Step [200/391] Loss: 0.6132 LR: 0.0001
# Epoch [219/300], Step [300/391] Loss: 0.6858 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [220/300], Step [100/391] Loss: 0.6898 LR: 0.0001
# Epoch [220/300], Step [200/391] Loss: 0.7766 LR: 0.0001
# Epoch [220/300], Step [300/391] Loss: 0.7576 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [221/300], Step [100/391] Loss: 0.6921 LR: 0.0001
# Epoch [221/300], Step [200/391] Loss: 0.8012 LR: 0.0001
# Epoch [221/300], Step [300/391] Loss: 0.6711 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [222/300], Step [100/391] Loss: 0.7018 LR: 0.0001
# Epoch [222/300], Step [200/391] Loss: 0.6725 LR: 0.0001
# Epoch [222/300], Step [300/391] Loss: 0.7272 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [223/300], Step [100/391] Loss: 0.8090 LR: 0.0001
# Epoch [223/300], Step [200/391] Loss: 0.7948 LR: 0.0001
# Epoch [223/300], Step [300/391] Loss: 0.7751 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [224/300], Step [100/391] Loss: 0.7602 LR: 0.0001
# Epoch [224/300], Step [200/391] Loss: 0.6152 LR: 0.0001
# Epoch [224/300], Step [300/391] Loss: 0.7367 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [225/300], Step [100/391] Loss: 0.7000 LR: 0.0001
# Epoch [225/300], Step [200/391] Loss: 0.6287 LR: 0.0001
# Epoch [225/300], Step [300/391] Loss: 0.6484 LR: 0.0001
# Accuracy of the network : 72 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [226/300], Step [100/391] Loss: 0.9809 LR: 0.0001
# Epoch [226/300], Step [200/391] Loss: 0.7028 LR: 0.0001
# Epoch [226/300], Step [300/391] Loss: 0.6538 LR: 0.0001
# Accuracy of the network : 72 %
# Using clean
# Epoch [227/300], Step [100/391] Loss: 0.6038 LR: 0.0001
# Epoch [227/300], Step [200/391] Loss: 0.8161 LR: 0.0001
# Epoch [227/300], Step [300/391] Loss: 0.5274 LR: 0.0001
# Accuracy of the network : 73 %
# Using clean
# Epoch [228/300], Step [100/391] Loss: 0.7221 LR: 0.0000
# Epoch [228/300], Step [200/391] Loss: 0.7478 LR: 0.0000
# Epoch [228/300], Step [300/391] Loss: 0.7415 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [229/300], Step [100/391] Loss: 0.7513 LR: 0.0000
# Epoch [229/300], Step [200/391] Loss: 0.7606 LR: 0.0000
# Epoch [229/300], Step [300/391] Loss: 0.5983 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [230/300], Step [100/391] Loss: 0.6276 LR: 0.0000
# Epoch [230/300], Step [200/391] Loss: 0.6899 LR: 0.0000
# Epoch [230/300], Step [300/391] Loss: 0.6638 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [231/300], Step [100/391] Loss: 0.6174 LR: 0.0000
# Epoch [231/300], Step [200/391] Loss: 0.6471 LR: 0.0000
# Epoch [231/300], Step [300/391] Loss: 0.7927 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [232/300], Step [100/391] Loss: 0.8109 LR: 0.0000
# Epoch [232/300], Step [200/391] Loss: 0.6814 LR: 0.0000
# Epoch [232/300], Step [300/391] Loss: 0.5321 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [233/300], Step [100/391] Loss: 0.6559 LR: 0.0000
# Epoch [233/300], Step [200/391] Loss: 0.7631 LR: 0.0000
# Epoch [233/300], Step [300/391] Loss: 0.7466 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [234/300], Step [100/391] Loss: 0.7560 LR: 0.0000
# Epoch [234/300], Step [200/391] Loss: 0.5996 LR: 0.0000
# Epoch [234/300], Step [300/391] Loss: 0.6117 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [235/300], Step [100/391] Loss: 0.7466 LR: 0.0000
# Epoch [235/300], Step [200/391] Loss: 0.6979 LR: 0.0000
# Epoch [235/300], Step [300/391] Loss: 0.6965 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [236/300], Step [100/391] Loss: 0.7230 LR: 0.0000
# Epoch [236/300], Step [200/391] Loss: 0.6158 LR: 0.0000
# Epoch [236/300], Step [300/391] Loss: 0.8461 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [237/300], Step [100/391] Loss: 0.7202 LR: 0.0000
# Epoch [237/300], Step [200/391] Loss: 0.7250 LR: 0.0000
# Epoch [237/300], Step [300/391] Loss: 0.7163 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [238/300], Step [100/391] Loss: 0.7010 LR: 0.0000
# Epoch [238/300], Step [200/391] Loss: 0.5409 LR: 0.0000
# Epoch [238/300], Step [300/391] Loss: 0.7282 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [239/300], Step [100/391] Loss: 0.8420 LR: 0.0000
# Epoch [239/300], Step [200/391] Loss: 0.6103 LR: 0.0000
# Epoch [239/300], Step [300/391] Loss: 0.7936 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [240/300], Step [100/391] Loss: 0.6946 LR: 0.0000
# Epoch [240/300], Step [200/391] Loss: 0.8302 LR: 0.0000
# Epoch [240/300], Step [300/391] Loss: 0.6935 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [241/300], Step [100/391] Loss: 0.7364 LR: 0.0000
# Epoch [241/300], Step [200/391] Loss: 0.7479 LR: 0.0000
# Epoch [241/300], Step [300/391] Loss: 0.7639 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [242/300], Step [100/391] Loss: 0.7034 LR: 0.0000
# Epoch [242/300], Step [200/391] Loss: 0.7141 LR: 0.0000
# Epoch [242/300], Step [300/391] Loss: 0.4981 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [243/300], Step [100/391] Loss: 0.8142 LR: 0.0000
# Epoch [243/300], Step [200/391] Loss: 0.6885 LR: 0.0000
# Epoch [243/300], Step [300/391] Loss: 0.7169 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [244/300], Step [100/391] Loss: 0.7292 LR: 0.0000
# Epoch [244/300], Step [200/391] Loss: 0.8121 LR: 0.0000
# Epoch [244/300], Step [300/391] Loss: 0.6818 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [245/300], Step [100/391] Loss: 0.6537 LR: 0.0000
# Epoch [245/300], Step [200/391] Loss: 0.6278 LR: 0.0000
# Epoch [245/300], Step [300/391] Loss: 0.7939 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [246/300], Step [100/391] Loss: 0.7129 LR: 0.0000
# Epoch [246/300], Step [200/391] Loss: 0.5723 LR: 0.0000
# Epoch [246/300], Step [300/391] Loss: 0.6821 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [247/300], Step [100/391] Loss: 0.6919 LR: 0.0000
# Epoch [247/300], Step [200/391] Loss: 0.6669 LR: 0.0000
# Epoch [247/300], Step [300/391] Loss: 0.6766 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [248/300], Step [100/391] Loss: 0.7397 LR: 0.0000
# Epoch [248/300], Step [200/391] Loss: 0.8025 LR: 0.0000
# Epoch [248/300], Step [300/391] Loss: 0.8182 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [249/300], Step [100/391] Loss: 0.6406 LR: 0.0000
# Epoch [249/300], Step [200/391] Loss: 0.6894 LR: 0.0000
# Epoch [249/300], Step [300/391] Loss: 0.7858 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [250/300], Step [100/391] Loss: 0.7912 LR: 0.0000
# Epoch [250/300], Step [200/391] Loss: 0.7594 LR: 0.0000
# Epoch [250/300], Step [300/391] Loss: 0.6623 LR: 0.0000
# Accuracy of the network : 72 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [251/300], Step [100/391] Loss: 0.8690 LR: 0.0000
# Epoch [251/300], Step [200/391] Loss: 0.7053 LR: 0.0000
# Epoch [251/300], Step [300/391] Loss: 0.7569 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [252/300], Step [100/391] Loss: 0.7282 LR: 0.0000
# Epoch [252/300], Step [200/391] Loss: 0.5987 LR: 0.0000
# Epoch [252/300], Step [300/391] Loss: 0.6564 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [253/300], Step [100/391] Loss: 0.8195 LR: 0.0000
# Epoch [253/300], Step [200/391] Loss: 0.7840 LR: 0.0000
# Epoch [253/300], Step [300/391] Loss: 0.6439 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [254/300], Step [100/391] Loss: 0.6648 LR: 0.0000
# Epoch [254/300], Step [200/391] Loss: 0.6100 LR: 0.0000
# Epoch [254/300], Step [300/391] Loss: 0.5880 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [255/300], Step [100/391] Loss: 0.6484 LR: 0.0000
# Epoch [255/300], Step [200/391] Loss: 0.6276 LR: 0.0000
# Epoch [255/300], Step [300/391] Loss: 0.7584 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [256/300], Step [100/391] Loss: 0.6306 LR: 0.0000
# Epoch [256/300], Step [200/391] Loss: 0.7653 LR: 0.0000
# Epoch [256/300], Step [300/391] Loss: 0.8192 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [257/300], Step [100/391] Loss: 0.7559 LR: 0.0000
# Epoch [257/300], Step [200/391] Loss: 0.7150 LR: 0.0000
# Epoch [257/300], Step [300/391] Loss: 0.6704 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [258/300], Step [100/391] Loss: 0.5449 LR: 0.0000
# Epoch [258/300], Step [200/391] Loss: 0.7102 LR: 0.0000
# Epoch [258/300], Step [300/391] Loss: 0.6016 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [259/300], Step [100/391] Loss: 0.6241 LR: 0.0000
# Epoch [259/300], Step [200/391] Loss: 0.7675 LR: 0.0000
# Epoch [259/300], Step [300/391] Loss: 0.6800 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [260/300], Step [100/391] Loss: 0.5602 LR: 0.0000
# Epoch [260/300], Step [200/391] Loss: 0.7206 LR: 0.0000
# Epoch [260/300], Step [300/391] Loss: 0.7517 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [261/300], Step [100/391] Loss: 0.6682 LR: 0.0000
# Epoch [261/300], Step [200/391] Loss: 0.7766 LR: 0.0000
# Epoch [261/300], Step [300/391] Loss: 0.6158 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [262/300], Step [100/391] Loss: 0.6403 LR: 0.0000
# Epoch [262/300], Step [200/391] Loss: 0.6089 LR: 0.0000
# Epoch [262/300], Step [300/391] Loss: 0.5457 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [263/300], Step [100/391] Loss: 0.5998 LR: 0.0000
# Epoch [263/300], Step [200/391] Loss: 0.6681 LR: 0.0000
# Epoch [263/300], Step [300/391] Loss: 0.6838 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [264/300], Step [100/391] Loss: 0.6738 LR: 0.0000
# Epoch [264/300], Step [200/391] Loss: 0.8285 LR: 0.0000
# Epoch [264/300], Step [300/391] Loss: 0.4725 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [265/300], Step [100/391] Loss: 0.7145 LR: 0.0000
# Epoch [265/300], Step [200/391] Loss: 0.6773 LR: 0.0000
# Epoch [265/300], Step [300/391] Loss: 0.5393 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [266/300], Step [100/391] Loss: 0.7118 LR: 0.0000
# Epoch [266/300], Step [200/391] Loss: 0.6958 LR: 0.0000
# Epoch [266/300], Step [300/391] Loss: 0.9366 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [267/300], Step [100/391] Loss: 0.8906 LR: 0.0000
# Epoch [267/300], Step [200/391] Loss: 0.6703 LR: 0.0000
# Epoch [267/300], Step [300/391] Loss: 0.6155 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [268/300], Step [100/391] Loss: 0.6794 LR: 0.0000
# Epoch [268/300], Step [200/391] Loss: 0.7411 LR: 0.0000
# Epoch [268/300], Step [300/391] Loss: 0.6820 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [269/300], Step [100/391] Loss: 0.5667 LR: 0.0000
# Epoch [269/300], Step [200/391] Loss: 0.7714 LR: 0.0000
# Epoch [269/300], Step [300/391] Loss: 0.6839 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [270/300], Step [100/391] Loss: 0.6444 LR: 0.0000
# Epoch [270/300], Step [200/391] Loss: 0.6977 LR: 0.0000
# Epoch [270/300], Step [300/391] Loss: 0.6148 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [271/300], Step [100/391] Loss: 0.8304 LR: 0.0000
# Epoch [271/300], Step [200/391] Loss: 0.6875 LR: 0.0000
# Epoch [271/300], Step [300/391] Loss: 0.7511 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [272/300], Step [100/391] Loss: 0.7834 LR: 0.0000
# Epoch [272/300], Step [200/391] Loss: 0.7392 LR: 0.0000
# Epoch [272/300], Step [300/391] Loss: 0.5387 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [273/300], Step [100/391] Loss: 0.7887 LR: 0.0000
# Epoch [273/300], Step [200/391] Loss: 0.5864 LR: 0.0000
# Epoch [273/300], Step [300/391] Loss: 0.6707 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [274/300], Step [100/391] Loss: 0.7408 LR: 0.0000
# Epoch [274/300], Step [200/391] Loss: 0.5759 LR: 0.0000
# Epoch [274/300], Step [300/391] Loss: 0.6842 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [275/300], Step [100/391] Loss: 0.5888 LR: 0.0000
# Epoch [275/300], Step [200/391] Loss: 0.6109 LR: 0.0000
# Epoch [275/300], Step [300/391] Loss: 0.8243 LR: 0.0000
# Accuracy of the network : 73 %
# !!!Checkpoint saved!!!
# Using clean
# Epoch [276/300], Step [100/391] Loss: 0.6280 LR: 0.0000
# Epoch [276/300], Step [200/391] Loss: 0.5906 LR: 0.0000
# Epoch [276/300], Step [300/391] Loss: 0.6757 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [277/300], Step [100/391] Loss: 0.7924 LR: 0.0000
# Epoch [277/300], Step [200/391] Loss: 0.7599 LR: 0.0000
# Epoch [277/300], Step [300/391] Loss: 0.6997 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [278/300], Step [100/391] Loss: 0.5258 LR: 0.0000
# Epoch [278/300], Step [200/391] Loss: 0.7546 LR: 0.0000
# Epoch [278/300], Step [300/391] Loss: 0.6884 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [279/300], Step [100/391] Loss: 0.7089 LR: 0.0000
# Epoch [279/300], Step [200/391] Loss: 0.7698 LR: 0.0000
# Epoch [279/300], Step [300/391] Loss: 0.7191 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [280/300], Step [100/391] Loss: 0.6669 LR: 0.0000
# Epoch [280/300], Step [200/391] Loss: 0.7044 LR: 0.0000
# Epoch [280/300], Step [300/391] Loss: 0.7705 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [281/300], Step [100/391] Loss: 0.6539 LR: 0.0000
# Epoch [281/300], Step [200/391] Loss: 0.6857 LR: 0.0000
# Epoch [281/300], Step [300/391] Loss: 0.6687 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [282/300], Step [100/391] Loss: 0.9215 LR: 0.0000
# Epoch [282/300], Step [200/391] Loss: 0.8184 LR: 0.0000
# Epoch [282/300], Step [300/391] Loss: 0.7097 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [283/300], Step [100/391] Loss: 0.6584 LR: 0.0000
# Epoch [283/300], Step [200/391] Loss: 0.7551 LR: 0.0000
# Epoch [283/300], Step [300/391] Loss: 0.7332 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [284/300], Step [100/391] Loss: 0.7102 LR: 0.0000
# Epoch [284/300], Step [200/391] Loss: 0.7903 LR: 0.0000
# Epoch [284/300], Step [300/391] Loss: 0.6454 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [285/300], Step [100/391] Loss: 0.8066 LR: 0.0000
# Epoch [285/300], Step [200/391] Loss: 0.7672 LR: 0.0000
# Epoch [285/300], Step [300/391] Loss: 0.6618 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [286/300], Step [100/391] Loss: 0.6793 LR: 0.0000
# Epoch [286/300], Step [200/391] Loss: 0.6511 LR: 0.0000
# Epoch [286/300], Step [300/391] Loss: 0.7129 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [287/300], Step [100/391] Loss: 0.6593 LR: 0.0000
# Epoch [287/300], Step [200/391] Loss: 0.6633 LR: 0.0000
# Epoch [287/300], Step [300/391] Loss: 0.6615 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [288/300], Step [100/391] Loss: 0.7653 LR: 0.0000
# Epoch [288/300], Step [200/391] Loss: 0.6571 LR: 0.0000
# Epoch [288/300], Step [300/391] Loss: 0.6112 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [289/300], Step [100/391] Loss: 0.5745 LR: 0.0000
# Epoch [289/300], Step [200/391] Loss: 0.7181 LR: 0.0000
# Epoch [289/300], Step [300/391] Loss: 0.7197 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [290/300], Step [100/391] Loss: 0.8179 LR: 0.0000
# Epoch [290/300], Step [200/391] Loss: 0.5798 LR: 0.0000
# Epoch [290/300], Step [300/391] Loss: 0.7547 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [291/300], Step [100/391] Loss: 0.7250 LR: 0.0000
# Epoch [291/300], Step [200/391] Loss: 0.7236 LR: 0.0000
# Epoch [291/300], Step [300/391] Loss: 0.7112 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [292/300], Step [100/391] Loss: 0.8193 LR: 0.0000
# Epoch [292/300], Step [200/391] Loss: 0.9466 LR: 0.0000
# Epoch [292/300], Step [300/391] Loss: 0.8369 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [293/300], Step [100/391] Loss: 0.7206 LR: 0.0000
# Epoch [293/300], Step [200/391] Loss: 0.6433 LR: 0.0000
# Epoch [293/300], Step [300/391] Loss: 0.8839 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [294/300], Step [100/391] Loss: 0.7941 LR: 0.0000
# Epoch [294/300], Step [200/391] Loss: 0.6769 LR: 0.0000
# Epoch [294/300], Step [300/391] Loss: 0.6380 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [295/300], Step [100/391] Loss: 0.5977 LR: 0.0000
# Epoch [295/300], Step [200/391] Loss: 0.6118 LR: 0.0000
# Epoch [295/300], Step [300/391] Loss: 0.8097 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [296/300], Step [100/391] Loss: 0.6988 LR: 0.0000
# Epoch [296/300], Step [200/391] Loss: 0.6897 LR: 0.0000
# Epoch [296/300], Step [300/391] Loss: 0.7804 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [297/300], Step [100/391] Loss: 0.5675 LR: 0.0000
# Epoch [297/300], Step [200/391] Loss: 0.7107 LR: 0.0000
# Epoch [297/300], Step [300/391] Loss: 0.7759 LR: 0.0000
# Accuracy of the network : 73 %
# Using clean
# Epoch [298/300], Step [100/391] Loss: 0.6706 LR: 0.0000
# Epoch [298/300], Step [200/391] Loss: 0.6659 LR: 0.0000
# Epoch [298/300], Step [300/391] Loss: 0.6648 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [299/300], Step [100/391] Loss: 0.6577 LR: 0.0000
# Epoch [299/300], Step [200/391] Loss: 0.8438 LR: 0.0000
# Epoch [299/300], Step [300/391] Loss: 0.6657 LR: 0.0000
# Accuracy of the network : 72 %
# Using clean
# Epoch [300/300], Step [100/391] Loss: 0.7050 LR: 0.0000
# Epoch [300/300], Step [200/391] Loss: 0.7816 LR: 0.0000
# Epoch [300/300], Step [300/391] Loss: 0.6727 LR: 0.0000
# Accuracy of the network : 73 %
# !!!Checkpoint saved!!!
# Finished Training

# %%
plt.plot(accuracy_plot)
plt.show()

# %%
plt.plot(loss_plot)
plt.show()

# %%
PATH = './cifar_net_4.pth'
torch.save(net.state_dict(), PATH)

# %%
np.save('./acc_4.npy', accuracy_plot)
np.save('./loss_4.npy', loss_plot)

# %%
acc_data = np.load('./acc_4.npy')
plt.plot(acc_data)
plt.show()

# %%
loss_data = np.load('./loss_4.npy')
plt.plot(loss_data)
plt.show()

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: plane is 77.9 %
# Accuracy for class: car   is 83.8 %
# Accuracy for class: bird  is 62.4 %
# Accuracy for class: cat   is 56.3 %
# Accuracy for class: deer  is 68.6 %
# Accuracy for class: dog   is 60.8 %
# Accuracy for class: frog  is 79.2 %
# Accuracy for class: horse is 77.0 %
# Accuracy for class: ship  is 85.3 %
# Accuracy for class: truck is 80.3 %
